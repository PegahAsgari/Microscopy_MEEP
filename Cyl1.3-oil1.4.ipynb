# %%
# first I want to make the geometry

import meep as mp
import math
import matplotlib
#matplotlib.use('agg')
import numpy as np
import matplotlib.pyplot as plt
from meep.materials import BK7
import h5py

# wvl_min = 0.760  # min wavelength
# wvl_max = 0.940  # max wavelength
# fmin = 1 / wvl_max  # min frequency
# fmax = 1 / wvl_min  # max frequency
# fcen = 0.5 * (fmin + fmax)  # center frequency
# df = fmax - fmin  # frequency width
# nfreq = 200  # number of frequency bins
wvl_cent = 0.830  # wavelength
fcen=1/wvl_cent
df =1 #pulse width (in frequency)

s = 20
resolution = 50
dpml = 2

cell_size = mp.Vector3(s,s,0)

boundary_layers = [mp.PML(thickness=dpml)]

beam_x0 = mp.Vector3(0,2.5)    # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0,1,0).rotate(mp.Vector3(0,0,1),math.radians(rot_angle))  # beam propagation direction
beam_w0 = 0.3  # beam waist radius
beam_E0 = mp.Vector3(0,0,1)

sources = [mp.GaussianBeamSource(src=mp.GaussianSource(fcen,fwidth=df),
                                 center=mp.Vector3(0,-0.5*s+dpml+1.0),
                                 size=mp.Vector3(s),
                                 beam_x0=beam_x0,
                                 beam_kdir=beam_kdir,
                                 beam_w0=beam_w0,
                                 beam_E0=beam_E0,
                                 amplitude=3)]

# %%
# cover slip
thickness_slide=4
center_slide=-0.5*s+dpml+0.5*thickness_slide
thickness_medium=s-2*dpml-thickness_slide
center_medium=0.5*s-dpml-0.5*thickness_medium

distance_cylender_slide=0.5
Radius_cylinder=2.5
center_cylinder=-0.5*s+dpml+thickness_slide+distance_cylender_slide+Radius_cylinder



geometry = [mp.Block(mp.Vector3(s-2*dpml,thickness_slide,mp.inf),
                     center=mp.Vector3(0,center_slide,0),
                     material=BK7),
            mp.Block(mp.Vector3(s-2*dpml,thickness_medium,mp.inf),
                     center=mp.Vector3(0,center_medium,0),
                     material=mp.Medium(epsilon=1.79)),
            mp.Cylinder(radius=Radius_cylinder,center=mp.Vector3(0,center_cylinder,0),
                        axis=mp.Vector3(0,0,1),
                        material=mp.Medium(epsilon=1.96),
                        height=4),
            ]

# %%
sim = mp.Simulation(cell_size=cell_size,
                    boundary_layers=boundary_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution,
                    force_complex_fields=True)

#
sim.run(mp.at_beginning(mp.output_epsilon),
        mp.to_appended("ez", mp.at_every(1, mp.output_efield_z)),
        mp.to_appended("poy",mp.at_every(1,mp.output_poynting)),
        mp.to_appended("energy",mp.at_every(1,mp.output_dpwr)),
        until=55)

# sim.run(until=2)
sim.use_output_directory()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000720978 s
# Working in 2D dimensions.
# Computational cell is 20 x 20 x 0 with resolution 50
#      block, center = (0,-6,0)
#           size (16,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,2,0)
#           size (16,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.79,1.79,1.79)
#      cylinder, center = (0,-1,0)
#           radius 2.5, height 4, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1.96,1.96,1.96)
# time for set_epsilon = 1.87764 s
# lorentzian susceptibility: frequency=0.0982658, gamma=0
# lorentzian susceptibility: frequency=7.0679, gamma=0
# lorentzian susceptibility: frequency=12.9092, gamma=0
# -----------
# Meep: using complex fields.
# creating output file "./eps-000000.00.h5"...
# creating output file "./ez.h5"...
# creating output file "./poy.h5"...
# creating output file "./energy.h5"...
# Meep progress: 1.0/55.0 = 1.8% done in 5.0s, 270.4s to go
# on time step 100 (time=1), 0.0488914 s/step
# Meep progress: 2.0/55.0 = 3.6% done in 9.7s, 257.0s to go
# on time step 200 (time=2), 0.0469242 s/step
# Meep progress: 3.0/55.0 = 5.5% done in 14.4s, 250.3s to go
# on time step 300 (time=3), 0.0474162 s/step
# Meep progress: 4.0/55.0 = 7.3% done in 19.1s, 244.1s to go
# on time step 400 (time=4), 0.0470132 s/step
# Meep progress: 5.0/55.0 = 9.1% done in 23.9s, 238.5s to go
# on time step 500 (time=5), 0.0471042 s/step
# Meep progress: 6.0/55.0 = 10.9% done in 28.7s, 234.2s to go
# on time step 600 (time=6), 0.0482876 s/step
# Meep progress: 7.0/55.0 = 12.7% done in 33.6s, 230.5s to go
# on time step 700 (time=7), 0.049358 s/step
# Meep progress: 8.0/55.0 = 14.5% done in 38.5s, 226.1s to go
# on time step 800 (time=8), 0.0486062 s/step
# Meep progress: 9.0/55.0 = 16.4% done in 43.4s, 222.0s to go
# on time step 900 (time=9), 0.0495765 s/step
# Meep progress: 9.99/55.0 = 18.2% done in 47.4s, 213.7s to go
# on time step 999 (time=9.99), 0.0404049 s/step
# Meep progress: 10.71/55.0 = 19.5% done in 51.5s, 212.9s to go
# on time step 1071 (time=10.71), 0.0561133 s/step
# Meep progress: 11.42/55.0 = 20.8% done in 55.5s, 211.8s to go
# on time step 1142 (time=11.42), 0.0567721 s/step
# Meep progress: 12.16/55.0 = 22.1% done in 59.5s, 209.8s to go
# on time step 1216 (time=12.16), 0.0544341 s/step
# Meep progress: 13.0/55.0 = 23.6% done in 63.6s, 205.4s to go
# on time step 1300 (time=13), 0.0481765 s/step
# Meep progress: 14.0/55.0 = 25.5% done in 68.2s, 199.7s to go
# on time step 1400 (time=14), 0.0461362 s/step
# Meep progress: 15.0/55.0 = 27.3% done in 72.8s, 194.2s to go
# on time step 1500 (time=15), 0.0461354 s/step
# Meep progress: 16.0/55.0 = 29.1% done in 77.4s, 188.8s to go
# on time step 1600 (time=16), 0.0462146 s/step
# Meep progress: 17.0/55.0 = 30.9% done in 82.1s, 183.5s to go
# on time step 1700 (time=17), 0.0463781 s/step
# Meep progress: 18.0/55.0 = 32.7% done in 86.7s, 178.3s to go
# on time step 1800 (time=18), 0.0465777 s/step
# Meep progress: 19.0/55.0 = 34.5% done in 91.4s, 173.1s to go
# on time step 1900 (time=19), 0.0463589 s/step
# Meep progress: 20.0/55.0 = 36.4% done in 96.0s, 168.0s to go
# on time step 2000 (time=20), 0.0462975 s/step
# Meep progress: 21.0/55.0 = 38.2% done in 100.6s, 162.9s to go
# on time step 2100 (time=21), 0.0463192 s/step
# Meep progress: 22.0/55.0 = 40.0% done in 105.3s, 157.9s to go
# on time step 2200 (time=22), 0.0466056 s/step
# Meep progress: 23.0/55.0 = 41.8% done in 109.9s, 152.9s to go
# on time step 2300 (time=23), 0.0462576 s/step
# Meep progress: 24.0/55.0 = 43.6% done in 114.6s, 148.0s to go
# on time step 2400 (time=24), 0.0463293 s/step
# Meep progress: 25.0/55.0 = 45.5% done in 119.2s, 143.0s to go
# on time step 2500 (time=25), 0.0465417 s/step
# Meep progress: 26.0/55.0 = 47.3% done in 123.9s, 138.1s to go
# on time step 2600 (time=26), 0.0464742 s/step
# Meep progress: 27.0/55.0 = 49.1% done in 128.5s, 133.3s to go
# on time step 2700 (time=27), 0.0463826 s/step
# Meep progress: 28.0/55.0 = 50.9% done in 133.1s, 128.4s to go
# on time step 2800 (time=28), 0.0464557 s/step
# Meep progress: 29.0/55.0 = 52.7% done in 137.8s, 123.5s to go
# on time step 2900 (time=29), 0.04625 s/step
# Meep progress: 30.0/55.0 = 54.5% done in 142.4s, 118.7s to go
# on time step 3000 (time=30), 0.0462412 s/step
# Meep progress: 31.0/55.0 = 56.4% done in 147.0s, 113.8s to go
# on time step 3100 (time=31), 0.0460864 s/step
# Meep progress: 32.0/55.0 = 58.2% done in 151.7s, 109.0s to go
# on time step 3200 (time=32), 0.0470256 s/step
# Meep progress: 33.0/55.0 = 60.0% done in 156.4s, 104.3s to go
# on time step 3300 (time=33), 0.0467548 s/step
# Meep progress: 34.0/55.0 = 61.8% done in 161.0s, 99.5s to go
# on time step 3400 (time=34), 0.0465406 s/step
# Meep progress: 35.0/55.0 = 63.6% done in 165.7s, 94.7s to go
# on time step 3500 (time=35), 0.0462854 s/step
# Meep progress: 36.0/55.0 = 65.5% done in 170.3s, 89.9s to go
# on time step 3600 (time=36), 0.046642 s/step
# Meep progress: 37.0/55.0 = 67.3% done in 175.0s, 85.1s to go
# on time step 3700 (time=37), 0.0464731 s/step
# Meep progress: 38.0/55.0 = 69.1% done in 179.6s, 80.4s to go
# on time step 3800 (time=38), 0.0466117 s/step
# Meep progress: 39.0/55.0 = 70.9% done in 184.2s, 75.6s to go
# on time step 3900 (time=39), 0.0460892 s/step
# Meep progress: 40.0/55.0 = 72.7% done in 188.9s, 70.8s to go
# on time step 4000 (time=40), 0.0462389 s/step
# Meep progress: 41.0/55.0 = 74.5% done in 193.5s, 66.1s to go
# on time step 4100 (time=41), 0.0464363 s/step
# Meep progress: 42.0/55.0 = 76.4% done in 198.1s, 61.3s to go
# on time step 4200 (time=42), 0.0463194 s/step
# Meep progress: 43.0/55.0 = 78.2% done in 202.9s, 56.6s to go
# on time step 4300 (time=43), 0.047848 s/step
# Meep progress: 44.0/55.0 = 80.0% done in 207.6s, 51.9s to go
# on time step 4400 (time=44), 0.046793 s/step
# Meep progress: 45.0/55.0 = 81.8% done in 212.2s, 47.2s to go
# on time step 4500 (time=45), 0.0462498 s/step
# Meep progress: 46.0/55.0 = 83.6% done in 216.8s, 42.4s to go
# on time step 4600 (time=46), 0.0461327 s/step
# Meep progress: 47.0/55.0 = 85.5% done in 221.5s, 37.7s to go
# on time step 4700 (time=47), 0.0461974 s/step
# Meep progress: 48.0/55.0 = 87.3% done in 226.1s, 33.0s to go
# on time step 4800 (time=48), 0.0462358 s/step
# Meep progress: 49.0/55.0 = 89.1% done in 230.8s, 28.3s to go
# on time step 4900 (time=49), 0.0468867 s/step
# Meep progress: 50.0/55.0 = 90.9% done in 235.4s, 23.5s to go
# on time step 5000 (time=50), 0.0464092 s/step
# Meep progress: 51.0/55.0 = 92.7% done in 240.1s, 18.8s to go
# on time step 5100 (time=51), 0.0466843 s/step
# Meep progress: 52.0/55.0 = 94.5% done in 244.8s, 14.1s to go
# on time step 5200 (time=52), 0.0467141 s/step
# Meep progress: 53.0/55.0 = 96.4% done in 249.4s, 9.4s to go
# on time step 5300 (time=53), 0.0466243 s/step
# Meep progress: 54.0/55.0 = 98.2% done in 254.1s, 4.7s to go
# on time step 5400 (time=54), 0.0466939 s/step
# Meep progress: 55.0/55.0 = 100.0% done in 258.8s, 0.0s to go
# run 0 finished at t = 55.0 (5500 timesteps)
# Meep: using output directory '-out'
# '-out'

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Dielectric)

# %%
hf=h5py.File('ez.h5','r')


n1 = hf.get('ez.i')
n1 = np.array(n1)
k=n1.shape
s=np.zeros((k[0],k[1]))

for i in range(k[2]):
    s = n1[:, :, i]
    plt.figure(i)
    plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
    plt.imshow(s.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
    plt.axis('off')
    plt.show()
